# %%
from openrtdynamics2.dsp import *
import json
import math
import numpy as np
import openrtdynamics2.lang as dy
import os

from vehicle_lib.vehicle_lib import *

# %%
# load track data
with open("track_data/simple_track.json", "r") as read_file:
    track_data = json.load(read_file)

# %%
#
# Demo: a vehicle controlled to follow a given path
#
#       Implemented using the code generator openrtdynamics 2 - https://pypi.org/project/openrtdynamics2/ .
#       This generates c++ code for Web Assembly to be run within the browser.
#

system = dy.enter_system()

velocity               = dy.system_input( dy.DataTypeFloat64(1), name='velocity',              default_value=23.75,  value_range=[0, 25],   title="vehicle velocity")
k_p                    = dy.system_input( dy.DataTypeFloat64(1), name='k_p',                   default_value=2.0,    value_range=[0, 10.0], title="controller gain")
disturbance_amplitude  = dy.system_input( dy.DataTypeFloat64(1), name='disturbance_amplitude', default_value=20.0,   value_range=[-45, 45], title="disturbance amplitude") * dy.float64(math.pi / 180.0)
sample_disturbance     = dy.system_input( dy.DataTypeInt32(1),   name='sample_disturbance',    default_value=50,     value_range=[0, 300],  title="disturbance position")

# parameters
wheelbase = 3.0

# sampling time
Ts = 0.01

# create storage for the reference path:
path = import_path_data(track_data)

# create placeholders for the plant output signals
x   = dy.signal()
y   = dy.signal()
psi = dy.signal()

# track the evolution of the closest point on the path to the vehicles position
d_star, x_r, y_r, psi_rr, K_r, Delta_l, tracked_index, Delta_index = track_projection_on_path(path, x, y)

#
# project the vehicle velocity onto the path yielding v_star 
#
# Used formula inside project_velocity_on_path:
#   v_star = d d_star / dt = v * cos( Delta_u ) / ( 1 - Delta_l * K(d_star) ) 
#

Delta_u = dy.signal() # feedback from control
v_star = project_velocity_on_path(velocity, Delta_u, Delta_l, K_r)

dy.append_primay_ouput(v_star,     'v_star')

#
# compute an enhanced (less noise) signal for the path orientation psi_r by integrating the 
# curvature profile and fusing the result with psi_rr to mitigate the integration drift.
#

psi_r, psi_r_dot = compute_path_orientation_from_curvature( Ts, v_star, psi_rr, K_r, L=1.0 )

dy.append_primay_ouput(psi_rr,    'psi_rr')
dy.append_primay_ouput(psi_r_dot, 'psi_r_dot')

# reference for the lateral distance
Delta_l_r = dy.float64(0.0) # zero in this example

dy.append_primay_ouput(Delta_l_r, 'Delta_l_r')

# feedback control
u = dy.PID_controller(r=Delta_l_r, y=Delta_l, Ts=0.01, kp=k_p)

# path tracking
# resulting lateral model u --> Delta_l : 1/s
Delta_u << dy.asin( dy.saturate(u / velocity, -0.99, 0.99) )
steering =  psi_r - psi + Delta_u
steering = dy.unwrap_angle(angle=steering, normalize_around_zero = True)

dy.append_primay_ouput(Delta_u, 'Delta_u')


#
# The model of the vehicle including a disturbance
#

# model the disturbance
disturbance_transient = np.concatenate(( cosra(50, 0, 1.0), co(10, 1.0), cosra(50, 1.0, 0) ))
steering_disturbance, i = dy.play(disturbance_transient, start_trigger=dy.counter() == sample_disturbance, auto_start=False)

# apply disturbance to the steering input
disturbed_steering = steering + steering_disturbance * disturbance_amplitude

# steering angle limit
disturbed_steering = dy.saturate(u=disturbed_steering, lower_limit=-math.pi/2.0, uppper_limit=math.pi/2.0)

# the model of the vehicle
x_, y_, psi_, x_dot, y_dot, psi_dot = discrete_time_bicycle_model(disturbed_steering, velocity, Ts, wheelbase)

# close the feedback loops
x << x_
y << y_
psi << psi_



#
# outputs: these are available for visualization in the html set-up
#

dy.append_primay_ouput(x, 'x')
dy.append_primay_ouput(y, 'y')
dy.append_primay_ouput(psi, 'psi')

dy.append_primay_ouput(steering, 'steering')

dy.append_primay_ouput(x_r, 'x_r')
dy.append_primay_ouput(y_r, 'y_r')
dy.append_primay_ouput(psi_r, 'psi_r')

dy.append_primay_ouput(Delta_l, 'Delta_l')

dy.append_primay_ouput(steering_disturbance, 'steering_disturbance')
dy.append_primay_ouput(disturbed_steering, 'disturbed_steering')

dy.append_primay_ouput(tracked_index, 'tracked_index')
dy.append_primay_ouput(Delta_index, 'Delta_index')

# generate code for Web Assembly (wasm), requires emcc (emscripten) to build
code_gen_results = dy.generate_code(template=dy.WasmRuntime(enable_tracing=False), folder="generated/path_curvature_following_control", build=True)

#
dy.clear()
# Out:
# New system (top-level system)
# New system as a subsystem of simulation
#
# -------- Compile connections (determine datatypes) --------
#
# Propagating datatypes...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# resolved all datatypes as far as possible in this update-run
# signals with fixed types:
#   - s53 (double [1])
#   - s120 (int32_t [1])
#   - s8 (double [2725] [1])
#   - s113 (double [1])
#   - s134 (double [1])
#   - k_p (double [1])
#   - s80 (int32_t [1])
#   - s54 (double [1])
#   - s12 (int32_t [1])
#   - s101 (double [1])
#   - velocity (double [1])
#   - s48 (double [1])
#   - s88 (double [1])
#   - s114 (double [1])
#   - disturbance_amplitude (double [1])
#   - s108 (double [1])
#   - s9 (double [2725] [1])
#   - s63 (double [1])
#   - s95 (double [1])
#   - s121 (int32_t [1])
#   - s49 (double [1])
#   - s4 (double [1])
#   - s109 (double [1])
#   - s70 (double [1])
#   - s10 (double [2725] [1])
#   - s103 (double [1])
#   - s143 (double [1])
#   - s64 (double [1])
#   - s77 (int32_t [1])
#   - s131 (double [1])
#   - sample_disturbance (int32_t [1])
#   - s104 (double [1])
#   - s35 (int32_t [1])
#   - s11 (double [2725] [1])
#   - s58 (double [1])
#   - s7 (double [2725] [1])
#   - s85 (double [1])
#   - s92 (double [1])
#   - s46 (double [1])
#   - s119 (double [110] [1])
#   - s59 (double [1])
#   - Delta_l_r (double [1])
# signals with proposed types:
#   - s126 type proposal: (int32_t [1])
#   - s100 type proposal: (double [1])
#   - s47 type proposal: (double [1])
#   - steering_disturbance type proposal: (double [1])
#   - s118 type proposal: (bool [1])
#   - s127 type proposal: (int32_t [1])
#   - s129 type proposal: (double [1])
#   - s102 type proposal: (double [1])
#   - s115 type proposal: (bool [1])
#   - s130 type proposal: (double [1])
#   - s50 type proposal: (bool [1])
#   - s116 type proposal: (double [1])
#   - steering type proposal: (double [1])
#   - s51 type proposal: (double [1])
#   - s132 type proposal: (bool [1])
#   - s52 type proposal: (double [1])
#   - s105 type proposal: (bool [1])
#   - s133 type proposal: (double [1])
#   - s106 type proposal: (double [1])
#   - s107 type proposal: (double [1])
#   - tracked_index type proposal: (int32_t [1])
#   - s135 type proposal: (bool [1])
#   - s55 type proposal: (bool [1])
#   - disturbed_steering type proposal: (double [1])
#   - s13 type proposal: (int32_t [1])
#   - s122 type proposal: (bool [1])
#   - s56 type proposal: (double [1])
#   - s57 type proposal: (double [1])
#   - s123_paused type proposal: (bool [1])
#   - s14 type proposal: (int32_t [1])
#   - s110 type proposal: (bool [1])
#   - s137 type proposal: (double [1])
#   - s15 type proposal: (int32_t [1])
#   - s124_stepwidth type proposal: (int32_t [1])
#   - s111 type proposal: (double [1])
#   - s138 type proposal: (double [1])
#   - s125 type proposal: (int32_t [1])
#   - s16 type proposal: (int32_t [1])
#   - s112 type proposal: (double [1])
#   - s139 type proposal: (double [1])
#   - psi type proposal: (double [1])
#   - s86 type proposal: (double [1])
#   - s17 type proposal: (double [1])
#   - s74 type proposal: (double [1])
#   - s140 type proposal: (double [1])
#   - s60 type proposal: (bool [1])
#   - s18 type proposal: (int32_t [1])
#   - s34 type proposal: (int32_t [1])
#   - psi_r_dot type proposal: (double [1])
#   - s61 type proposal: (double [1])
#   - s141 type proposal: (double [1])
#   - s36 type proposal: (int32_t [1])
#   - s19 type proposal: (double [1])
#   - s62 type proposal: (double [1])
#   - s142 type proposal: (double [1])
#   - s89 type proposal: (double [1])
#   - s37 type proposal: (double [1])
#   - s76 type proposal: (double [1])
#   - s20 type proposal: (double [1])
#   - s90 type proposal: (double [1])
#   - y_r type proposal: (double [1])
#   - s91 type proposal: (double [1])
#   - s21 type proposal: (double [1])
#   - s144 type proposal: (double [1])
#   - x_r type proposal: (double [1])
#   - s65 type proposal: (bool [1])
#   - s22 type proposal: (double [1])
#   - s78 type proposal: (int32_t [1])
#   - s145 type proposal: (double [1])
#   - s66 type proposal: (double [1])
#   - psi_rr type proposal: (double [1])
#   - s23 type proposal: (double [1])
#   - s93 type proposal: (bool [1])
#   - s79_shared_couter type proposal: (int32_t [1])
#   - s146 type proposal: (double [1])
#   - Delta_l type proposal: (double [1])
#   - s41 type proposal: (double [1])
#   - s94 type proposal: (double [1])
#   - s24 type proposal: (double [1])
#   - s68 type proposal: (double [1])
#   - s147 type proposal: (double [1])
#   - s42 type proposal: (double [1])
#   - s25_tracker_distance type proposal: (double [1])
#   - s81 type proposal: (bool [1])
#   - s69 type proposal: (double [1])
#   - s26 type proposal: (double [1])
#   - x type proposal: (double [1])
#   - s43 type proposal: (double [1])
#   - s82 type proposal: (double [1])
#   - s84 type proposal: (double [1])
#   - s96 type proposal: (bool [1])
#   - s149 type proposal: (double [1])
#   - s27_minimal_distance_reached type proposal: (bool [1])
#   - s44 type proposal: (double [1])
#   - s5 type proposal: (double [1])
#   - psi_r type proposal: (double [1])
#   - s28 type proposal: (int32_t [1])type inherit from s15
#   - s97 type proposal: (double [1])
#   - s29 type proposal: (double [1])type inherit from s26
#   - s45 type proposal: (double [1])
#   - s71 type proposal: (double [1])
#   - y type proposal: (double [1])
#   - Delta_u type proposal: (double [1])
#   - s30 type proposal: (bool [1])type inherit from s27_minimal_distance_reached
#   - s151 type proposal: (double [1])
#   - s72 type proposal: (double [1])
#   - s99 type proposal: (double [1])
#   - Delta_index type proposal: (int32_t [1])type inherit from s28
#   - s32_distance type proposal: (double [1])type inherit from s29
#   - v_star type proposal: (double [1])
# signals with undetermined types:
#   - s5 type proposal: (double [1])
#   - s13 type proposal: (int32_t [1])
#   - s14 type proposal: (int32_t [1])
#   - s15 type proposal: (int32_t [1])
#   - s16 type proposal: (int32_t [1])
#   - s17 type proposal: (double [1])
#   - s18 type proposal: (int32_t [1])
#   - s19 type proposal: (double [1])
#   - s20 type proposal: (double [1])
#   - s21 type proposal: (double [1])
#   - s22 type proposal: (double [1])
#   - s23 type proposal: (double [1])
#   - s24 type proposal: (double [1])
#   - s25_tracker_distance type proposal: (double [1])
#   - s26 type proposal: (double [1])
#   - s27_minimal_distance_reached type proposal: (bool [1])
#   - s28 type proposal: (int32_t [1])type inherit from s15
#   - s29 type proposal: (double [1])type inherit from s26
#   - s30 type proposal: (bool [1])type inherit from s27_minimal_distance_reached
#   - Delta_index type proposal: (int32_t [1])type inherit from s28
#   - s32_distance type proposal: (double [1])type inherit from s29
#   - tracked_index type proposal: (int32_t [1])
#   - s34 type proposal: (int32_t [1])
#   - s36 type proposal: (int32_t [1])
#   - s37 type proposal: (double [1])
#   - y_r type proposal: (double [1])
#   - x_r type proposal: (double [1])
#   - psi_rr type proposal: (double [1])
#   - s41 type proposal: (double [1])
#   - s42 type proposal: (double [1])
#   - s43 type proposal: (double [1])
#   - s44 type proposal: (double [1])
#   - s45 type proposal: (double [1])
#   - s47 type proposal: (double [1])
#   - s50 type proposal: (bool [1])
#   - s51 type proposal: (double [1])
#   - s52 type proposal: (double [1])
#   - s55 type proposal: (bool [1])
#   - s56 type proposal: (double [1])
#   - s57 type proposal: (double [1])
#   - s60 type proposal: (bool [1])
#   - s61 type proposal: (double [1])
#   - s62 type proposal: (double [1])
#   - s65 type proposal: (bool [1])
#   - s66 type proposal: (double [1])
#   - Delta_l type proposal: (double [1])
#   - s68 type proposal: (double [1])
#   - s69 type proposal: (double [1])
#   - s71 type proposal: (double [1])
#   - s72 type proposal: (double [1])
#   - v_star type proposal: (double [1])
#   - s74 type proposal: (double [1])
#   - psi_r_dot type proposal: (double [1])
#   - s76 type proposal: (double [1])
#   - s78 type proposal: (int32_t [1])
#   - s79_shared_couter type proposal: (int32_t [1])
#   - s81 type proposal: (bool [1])
#   - s82 type proposal: (double [1])
#   - psi_r type proposal: (double [1])
#   - s84 type proposal: (double [1])
#   - s86 type proposal: (double [1])
#   - s89 type proposal: (double [1])
#   - s90 type proposal: (double [1])
#   - s91 type proposal: (double [1])
#   - s93 type proposal: (bool [1])
#   - s94 type proposal: (double [1])
#   - s96 type proposal: (bool [1])
#   - s97 type proposal: (double [1])
#   - Delta_u type proposal: (double [1])
#   - s99 type proposal: (double [1])
#   - s100 type proposal: (double [1])
#   - s102 type proposal: (double [1])
#   - s105 type proposal: (bool [1])
#   - s106 type proposal: (double [1])
#   - s107 type proposal: (double [1])
#   - s110 type proposal: (bool [1])
#   - s111 type proposal: (double [1])
#   - s112 type proposal: (double [1])
#   - s115 type proposal: (bool [1])
#   - s116 type proposal: (double [1])
#   - steering type proposal: (double [1])
#   - s118 type proposal: (bool [1])
#   - s122 type proposal: (bool [1])
#   - s123_paused type proposal: (bool [1])
#   - s124_stepwidth type proposal: (int32_t [1])
#   - s125 type proposal: (int32_t [1])
#   - s126 type proposal: (int32_t [1])
#   - s127 type proposal: (int32_t [1])
#   - steering_disturbance type proposal: (double [1])
#   - s129 type proposal: (double [1])
#   - s130 type proposal: (double [1])
#   - s132 type proposal: (bool [1])
#   - s133 type proposal: (double [1])
#   - s135 type proposal: (bool [1])
#   - disturbed_steering type proposal: (double [1])
#   - s137 type proposal: (double [1])
#   - s138 type proposal: (double [1])
#   - s139 type proposal: (double [1])
#   - s140 type proposal: (double [1])
#   - s141 type proposal: (double [1])
#   - s142 type proposal: (double [1])
#   - s144 type proposal: (double [1])
#   - s145 type proposal: (double [1])
#   - s146 type proposal: (double [1])
#   - s147 type proposal: (double [1])
#   - x type proposal: (double [1])
#   - s149 type proposal: (double [1])
#   - y type proposal: (double [1])
#   - s151 type proposal: (double [1])
#   - psi type proposal: (double [1])
# signals with undetermined types:
# Now compiling (dept level = 1): Subsystem1000
#
# -------- replacing all anonymous signals  --------
#
#
# -------- Find dependencies for calcularing the outputs  --------
#
# getExecutionLine on level 0
# --- signals needed *indirectly* for s26 (through state update) --
# -> S s25_tracker_distance
# --- signals needed for s26 --
#   (no signals needed)
# added s26 (double [1]) type proposal: (double [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - s26
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
#   - s25_tracker_distance
# execution order:
#   - s26
# blocks whose states must be updated:
#   - 22
# getExecutionLine on level 1
# --- signals needed for s15 --
# -> S s14
# .  --- signals needed *indirectly* for s14 (through state update) --
# .  -> S s13
# .  --- signals needed for s14 --
# .    (no signals needed)
# .  added s14 (int32_t [1]) type proposal: (int32_t [1])
# -> S s12
# .  --- signals needed for s12 --
# .    (no signals needed)
# .  added s12 (int32_t [1])
# added s15 (int32_t [1]) type proposal: (int32_t [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - s14
#   - s12
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
#   - s13
# execution order:
#   - s14
#   - s12
#   - s15
# blocks whose states must be updated:
#   - 10
# getExecutionLine on level 2
# --- signals needed for s27_minimal_distance_reached --
# -> S s26
# .  has already been calculated in a previous traversion
# -> S s25_tracker_distance
# .  --- signals needed for s25_tracker_distance --
# .  -> S s24
# .  .  --- signals needed for s24 --
# .  .  -> S s22
# .  .  .  --- signals needed for s22 --
# .  .  .  -> S s20
# .  .  .  .  --- signals needed for s20 --
# .  .  .  .  -> S s17
# .  .  .  .  .  --- signals needed for s17 --
# .  .  .  .  .  -> S s8
# .  .  .  .  .  .    --> crosses system bounds
# .  .  .  .  .  .  added input dependency s8 (double [2725] [1])
# .  .  .  .  .  -> S s16
# .  .  .  .  .  .  --- signals needed for s16 --
# .  .  .  .  .  .  -> S s34
# .  .  .  .  .  .  .    --> crosses system bounds
# .  .  .  .  .  .  .  added input dependency s34 (int32_t [1]) type proposal: (int32_t [1])
# .  .  .  .  .  .  -> S s14
# .  .  .  .  .  .  .  has already been calculated in a previous traversion
# .  .  .  .  .  .  added s16 (int32_t [1]) type proposal: (int32_t [1])
# .  .  .  .  .  added s17 (double [1]) type proposal: (double [1])
# .  .  .  .  -> S x
# .  .  .  .  .    --> crosses system bounds
# .  .  .  .  .  added input dependency x (double [1]) type proposal: (double [1])
# .  .  .  .  added s20 (double [1]) type proposal: (double [1])
# .  .  .  -> S s20
# .  .  .  .  has already been calculated in this traversion
# .  .  .  added s22 (double [1]) type proposal: (double [1])
# .  .  -> S s23
# .  .  .  --- signals needed for s23 --
# .  .  .  -> S s21
# .  .  .  .  --- signals needed for s21 --
# .  .  .  .  -> S s19
# .  .  .  .  .  --- signals needed for s19 --
# .  .  .  .  .  -> S s9
# .  .  .  .  .  .    --> crosses system bounds
# .  .  .  .  .  .  added input dependency s9 (double [2725] [1])
# .  .  .  .  .  -> S s18
# .  .  .  .  .  .  --- signals needed for s18 --
# .  .  .  .  .  .  -> S s34
# .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  -> S s14
# .  .  .  .  .  .  .  has already been calculated in a previous traversion
# .  .  .  .  .  .  added s18 (int32_t [1]) type proposal: (int32_t [1])
# .  .  .  .  .  added s19 (double [1]) type proposal: (double [1])
# .  .  .  .  -> S y
# .  .  .  .  .    --> crosses system bounds
# .  .  .  .  .  added input dependency y (double [1]) type proposal: (double [1])
# .  .  .  .  added s21 (double [1]) type proposal: (double [1])
# .  .  .  -> S s21
# .  .  .  .  has already been calculated in this traversion
# .  .  .  added s23 (double [1]) type proposal: (double [1])
# .  .  added s24 (double [1]) type proposal: (double [1])
# .  added s25_tracker_distance (double [1]) type proposal: (double [1])
# added s27_minimal_distance_reached (bool [1]) type proposal: (bool [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - s26
#   - s8
#   - s34
#   - s14
#   - x
#   - s9
#   - s14
#   - y
# dependent sources (simulation inputs):
#   - s8
#   - s34
#   - x
#   - s9
#   - y
# dependent sources (through state-dependend blocks):
# execution order:
#   - s16
#   - s17
#   - s20
#   - s22
#   - s18
#   - s19
#   - s21
#   - s23
#   - s24
#   - s25_tracker_distance
#   - s27_minimal_distance_reached
# blocks whose states must be updated:
#
# -------- Build all execution paths  --------
#
# --------- Computing order 0 --------
# These sources are translated to (through their blocks via state-update):
# -- dependencySignalsThroughStates signals __ --
#   - s25_tracker_distance
#   - s13
# getExecutionLine on level 3
# has already been calculated in a previous traversion
# getExecutionLine on level 4
# --- signals needed for s13 --
# -> S s14
# .  has already been calculated in a previous traversion
# -> S s12
# .  has already been calculated in a previous traversion
# added s13 (int32_t [1]) type proposal: (int32_t [1])
# state update of blocks that yield the following output signals:
# All dependencies are resolved
# Now compiling (dept level = 0): simulation
#
# -------- replacing all anonymous signals  --------
#
#
# -------- Find dependencies for calcularing the outputs  --------
#
# getExecutionLine on level 0
# --- signals needed *indirectly* for psi (through state update) --
# -> S s151
# --- signals needed for psi --
#   (no signals needed)
# added psi (double [1]) type proposal: (double [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - psi
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
#   - s151
# execution order:
#   - psi
# blocks whose states must be updated:
#   - 145
# getExecutionLine on level 1
# --- signals needed for Delta_l --
# -> S s32_distance
# .  --- signals needed *indirectly* for s32_distance (through state update) --
# .  -> S s9
# .  -> S s8
# .  -> S x
# .  -> S y
# .  -> S s34
# .  --- signals needed for s32_distance --
# .  -> S s9
# .  .  --- signals needed *indirectly* for s9 (through state update) --
# .  .  --- signals needed for s9 --
# .  .    (no signals needed)
# .  .  added s9 (double [2725] [1])
# .  -> S s8
# .  .  --- signals needed *indirectly* for s8 (through state update) --
# .  .  --- signals needed for s8 --
# .  .    (no signals needed)
# .  .  added s8 (double [2725] [1])
# .  -> S x
# .  .  --- signals needed *indirectly* for x (through state update) --
# .  .  -> S s147
# .  .  --- signals needed for x --
# .  .    (no signals needed)
# .  .  added x (double [1]) type proposal: (double [1])
# .  -> S y
# .  .  --- signals needed *indirectly* for y (through state update) --
# .  .  -> S s149
# .  .  --- signals needed for y --
# .  .    (no signals needed)
# .  .  added y (double [1]) type proposal: (double [1])
# .  -> S s34
# .  .  --- signals needed *indirectly* for s34 (through state update) --
# .  .  -> S tracked_index
# .  .  --- signals needed for s34 --
# .  .    (no signals needed)
# .  .  added s34 (int32_t [1]) type proposal: (int32_t [1])
# .  added s32_distance (double [1]) type proposal: (double [1])type inherit from s29
# -> S s66
# .  --- signals needed for s66 --
# .  -> S s63
# .  .  --- signals needed for s63 --
# .  .    (no signals needed)
# .  .  added s63 (double [1])
# .  -> S s65
# .  .  --- signals needed for s65 --
# .  .  -> S s62
# .  .  .  --- signals needed for s62 --
# .  .  .  -> S s57
# .  .  .  .  --- signals needed for s57 --
# .  .  .  .  -> S s52
# .  .  .  .  .  --- signals needed for s52 --
# .  .  .  .  .  -> S s47
# .  .  .  .  .  .  --- signals needed for s47 --
# .  .  .  .  .  .  -> S s45
# .  .  .  .  .  .  .  --- signals needed for s45 --
# .  .  .  .  .  .  .  -> S psi_rr
# .  .  .  .  .  .  .  .  --- signals needed for psi_rr --
# .  .  .  .  .  .  .  .  -> S s10
# .  .  .  .  .  .  .  .  .  --- signals needed *indirectly* for s10 (through state update) --
# .  .  .  .  .  .  .  .  .  --- signals needed for s10 --
# .  .  .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  .  .  added s10 (double [2725] [1])
# .  .  .  .  .  .  .  .  -> S s36
# .  .  .  .  .  .  .  .  .  --- signals needed for s36 --
# .  .  .  .  .  .  .  .  .  -> S tracked_index
# .  .  .  .  .  .  .  .  .  .  --- signals needed for tracked_index --
# .  .  .  .  .  .  .  .  .  .  -> S s34
# .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  -> S Delta_index
# .  .  .  .  .  .  .  .  .  .  .  --- signals needed *indirectly* for Delta_index (through state update) --
# .  .  .  .  .  .  .  .  .  .  .  -> S s9
# .  .  .  .  .  .  .  .  .  .  .  -> S s8
# .  .  .  .  .  .  .  .  .  .  .  -> S x
# .  .  .  .  .  .  .  .  .  .  .  -> S y
# .  .  .  .  .  .  .  .  .  .  .  -> S s34
# .  .  .  .  .  .  .  .  .  .  .  --- signals needed for Delta_index --
# .  .  .  .  .  .  .  .  .  .  .  -> S s9
# .  .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  .  -> S s8
# .  .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  .  -> S x
# .  .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  .  -> S y
# .  .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  .  -> S s34
# .  .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  .  added Delta_index (int32_t [1]) type proposal: (int32_t [1])type inherit from s28
# .  .  .  .  .  .  .  .  .  .  added tracked_index (int32_t [1]) type proposal: (int32_t [1])
# .  .  .  .  .  .  .  .  .  -> S s35
# .  .  .  .  .  .  .  .  .  .  --- signals needed for s35 --
# .  .  .  .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  .  .  .  added s35 (int32_t [1])
# .  .  .  .  .  .  .  .  .  added s36 (int32_t [1]) type proposal: (int32_t [1])
# .  .  .  .  .  .  .  .  added psi_rr (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  -> S s44
# .  .  .  .  .  .  .  .  --- signals needed for s44 --
# .  .  .  .  .  .  .  .  -> S s42
# .  .  .  .  .  .  .  .  .  --- signals needed for s42 --
# .  .  .  .  .  .  .  .  .  -> S y
# .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  -> S y_r
# .  .  .  .  .  .  .  .  .  .  --- signals needed for y_r --
# .  .  .  .  .  .  .  .  .  .  -> S s9
# .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  -> S s36
# .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  added y_r (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  .  .  added s42 (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  .  -> S s43
# .  .  .  .  .  .  .  .  .  --- signals needed for s43 --
# .  .  .  .  .  .  .  .  .  -> S x
# .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  -> S x_r
# .  .  .  .  .  .  .  .  .  .  --- signals needed for x_r --
# .  .  .  .  .  .  .  .  .  .  -> S s8
# .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  -> S s36
# .  .  .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  .  .  added x_r (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  .  .  added s43 (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  .  added s44 (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  added s45 (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  -> S s46
# .  .  .  .  .  .  .  --- signals needed for s46 --
# .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  added s46 (double [1])
# .  .  .  .  .  .  added s47 (double [1]) type proposal: (double [1])
# .  .  .  .  .  -> S s51
# .  .  .  .  .  .  --- signals needed for s51 --
# .  .  .  .  .  .  -> S s48
# .  .  .  .  .  .  .  --- signals needed for s48 --
# .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  added s48 (double [1])
# .  .  .  .  .  .  -> S s50
# .  .  .  .  .  .  .  --- signals needed for s50 --
# .  .  .  .  .  .  .  -> S s47
# .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  -> S s49
# .  .  .  .  .  .  .  .  --- signals needed for s49 --
# .  .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  .  added s49 (double [1])
# .  .  .  .  .  .  .  added s50 (bool [1]) type proposal: (bool [1])
# .  .  .  .  .  .  added s51 (double [1]) type proposal: (double [1])
# .  .  .  .  .  added s52 (double [1]) type proposal: (double [1])
# .  .  .  .  -> S s56
# .  .  .  .  .  --- signals needed for s56 --
# .  .  .  .  .  -> S s53
# .  .  .  .  .  .  --- signals needed for s53 --
# .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  added s53 (double [1])
# .  .  .  .  .  -> S s55
# .  .  .  .  .  .  --- signals needed for s55 --
# .  .  .  .  .  .  -> S s52
# .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  -> S s54
# .  .  .  .  .  .  .  --- signals needed for s54 --
# .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  added s54 (double [1])
# .  .  .  .  .  .  added s55 (bool [1]) type proposal: (bool [1])
# .  .  .  .  .  added s56 (double [1]) type proposal: (double [1])
# .  .  .  .  added s57 (double [1]) type proposal: (double [1])
# .  .  .  -> S s61
# .  .  .  .  --- signals needed for s61 --
# .  .  .  .  -> S s58
# .  .  .  .  .  --- signals needed for s58 --
# .  .  .  .  .    (no signals needed)
# .  .  .  .  .  added s58 (double [1])
# .  .  .  .  -> S s60
# .  .  .  .  .  --- signals needed for s60 --
# .  .  .  .  .  -> S s52
# .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  -> S s59
# .  .  .  .  .  .  --- signals needed for s59 --
# .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  added s59 (double [1])
# .  .  .  .  .  added s60 (bool [1]) type proposal: (bool [1])
# .  .  .  .  added s61 (double [1]) type proposal: (double [1])
# .  .  .  added s62 (double [1]) type proposal: (double [1])
# .  .  -> S s64
# .  .  .  --- signals needed for s64 --
# .  .  .    (no signals needed)
# .  .  .  added s64 (double [1])
# .  .  added s65 (bool [1]) type proposal: (bool [1])
# .  added s66 (double [1]) type proposal: (double [1])
# added Delta_l (double [1]) type proposal: (double [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - s9
#   - s8
#   - x
#   - y
#   - s34
#   - s63
#   - s10
#   - s35
#   - s46
#   - s48
#   - s49
#   - s53
#   - s54
#   - s58
#   - s59
#   - s64
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
#   - s9
#   - s8
#   - x
#   - y
#   - s34
#   - s147
#   - s149
#   - tracked_index
#   - s9
#   - s8
#   - x
#   - y
#   - s34
# execution order:
#   - s9
#   - s8
#   - x
#   - y
#   - s34
#   - s32_distance
#   - s63
#   - s10
#   - Delta_index
#   - tracked_index
#   - s35
#   - s36
#   - psi_rr
#   - y_r
#   - s42
#   - x_r
#   - s43
#   - s44
#   - s45
#   - s46
#   - s47
#   - s48
#   - s49
#   - s50
#   - s51
#   - s52
#   - s53
#   - s54
#   - s55
#   - s56
#   - s57
#   - s58
#   - s59
#   - s60
#   - s61
#   - s62
#   - s64
#   - s65
#   - s66
#   - Delta_l
# blocks whose states must be updated:
#   - 25
#   - 5
#   - 4
#   - 141
#   - 143
#   - 27
#   - 6
#   - 25
# getExecutionLine on level 2
# --- signals needed for steering_disturbance --
# -> S s119
# .  --- signals needed *indirectly* for s119 (through state update) --
# .  --- signals needed for s119 --
# .    (no signals needed)
# .  added s119 (double [110] [1])
# -> S s127
# .  --- signals needed *indirectly* for s127 (through state update) --
# .  -> S s126
# .  --- signals needed for s127 --
# .    (no signals needed)
# .  added s127 (int32_t [1]) type proposal: (int32_t [1])
# added steering_disturbance (double [1]) type proposal: (double [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - s119
#   - s127
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
#   - s126
# execution order:
#   - s119
#   - s127
#   - steering_disturbance
# blocks whose states must be updated:
#   - 112
#   - 120
# getExecutionLine on level 3
# --- signals needed for psi_r --
# -> S s82
# .  --- signals needed *indirectly* for s82 (through state update) --
# .  -> S s76
# .  --- signals needed for s82 --
# .    (no signals needed)
# .  added s82 (double [1]) type proposal: (double [1])
# -> S s81
# .  --- signals needed for s81 --
# .  -> S s79_shared_couter
# .  .  --- signals needed *indirectly* for s79_shared_couter (through state update) --
# .  .  -> S s78
# .  .  --- signals needed for s79_shared_couter --
# .  .    (no signals needed)
# .  .  added s79_shared_couter (int32_t [1]) type proposal: (int32_t [1])
# .  -> S s80
# .  .  --- signals needed for s80 --
# .  .    (no signals needed)
# .  .  added s80 (int32_t [1])
# .  added s81 (bool [1]) type proposal: (bool [1])
# -> S psi_rr
# .  has already been calculated in a previous traversion
# added psi_r (double [1]) type proposal: (double [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - s82
#   - s79_shared_couter
#   - s80
#   - psi_rr
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
#   - s76
#   - s78
# execution order:
#   - s82
#   - s79_shared_couter
#   - s80
#   - s81
#   - psi_r
# blocks whose states must be updated:
#   - 75
#   - 72
# getExecutionLine on level 4
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - y_r
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 5
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - y
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 6
# --- signals needed for steering --
# -> S s112
# .  --- signals needed for s112 --
# .  -> S s107
# .  .  --- signals needed for s107 --
# .  .  -> S s102
# .  .  .  --- signals needed for s102 --
# .  .  .  -> S s100
# .  .  .  .  --- signals needed for s100 --
# .  .  .  .  -> S s99
# .  .  .  .  .  --- signals needed for s99 --
# .  .  .  .  .  -> S psi_r
# .  .  .  .  .  .  has already been calculated in a previous traversion
# .  .  .  .  .  -> S psi
# .  .  .  .  .  .  has already been calculated in a previous traversion
# .  .  .  .  .  added s99 (double [1]) type proposal: (double [1])
# .  .  .  .  -> S Delta_u
# .  .  .  .  .  --- signals needed for Delta_u --
# .  .  .  .  .  -> S s97
# .  .  .  .  .  .  --- signals needed for s97 --
# .  .  .  .  .  .  -> S s94
# .  .  .  .  .  .  .  --- signals needed for s94 --
# .  .  .  .  .  .  .  -> S s91
# .  .  .  .  .  .  .  .  --- signals needed for s91 --
# .  .  .  .  .  .  .  .  -> S s90
# .  .  .  .  .  .  .  .  .  --- signals needed for s90 --
# .  .  .  .  .  .  .  .  .  -> S k_p
# .  .  .  .  .  .  .  .  .  .    --> crosses system bounds
# .  .  .  .  .  .  .  .  .  .  added input dependency k_p (double [1])
# .  .  .  .  .  .  .  .  .  -> S s89
# .  .  .  .  .  .  .  .  .  .  --- signals needed for s89 --
# .  .  .  .  .  .  .  .  .  .  -> S Delta_l_r
# .  .  .  .  .  .  .  .  .  .  .  --- signals needed for Delta_l_r --
# .  .  .  .  .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  .  .  .  .  added Delta_l_r (double [1])
# .  .  .  .  .  .  .  .  .  .  -> S Delta_l
# .  .  .  .  .  .  .  .  .  .  .  has already been calculated in a previous traversion
# .  .  .  .  .  .  .  .  .  .  added s89 (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  .  .  added s90 (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  .  -> S velocity
# .  .  .  .  .  .  .  .  .    --> crosses system bounds
# .  .  .  .  .  .  .  .  .  added input dependency velocity (double [1])
# .  .  .  .  .  .  .  .  added s91 (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  .  -> S s93
# .  .  .  .  .  .  .  .  --- signals needed for s93 --
# .  .  .  .  .  .  .  .  -> S s91
# .  .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  .  -> S s92
# .  .  .  .  .  .  .  .  .  --- signals needed for s92 --
# .  .  .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  .  .  added s92 (double [1])
# .  .  .  .  .  .  .  .  added s93 (bool [1]) type proposal: (bool [1])
# .  .  .  .  .  .  .  added s94 (double [1]) type proposal: (double [1])
# .  .  .  .  .  .  -> S s96
# .  .  .  .  .  .  .  --- signals needed for s96 --
# .  .  .  .  .  .  .  -> S s94
# .  .  .  .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  .  .  .  -> S s95
# .  .  .  .  .  .  .  .  --- signals needed for s95 --
# .  .  .  .  .  .  .  .    (no signals needed)
# .  .  .  .  .  .  .  .  added s95 (double [1])
# .  .  .  .  .  .  .  added s96 (bool [1]) type proposal: (bool [1])
# .  .  .  .  .  .  added s97 (double [1]) type proposal: (double [1])
# .  .  .  .  .  added Delta_u (double [1]) type proposal: (double [1])
# .  .  .  .  added s100 (double [1]) type proposal: (double [1])
# .  .  .  -> S s101
# .  .  .  .  --- signals needed for s101 --
# .  .  .  .    (no signals needed)
# .  .  .  .  added s101 (double [1])
# .  .  .  added s102 (double [1]) type proposal: (double [1])
# .  .  -> S s106
# .  .  .  --- signals needed for s106 --
# .  .  .  -> S s103
# .  .  .  .  --- signals needed for s103 --
# .  .  .  .    (no signals needed)
# .  .  .  .  added s103 (double [1])
# .  .  .  -> S s105
# .  .  .  .  --- signals needed for s105 --
# .  .  .  .  -> S s102
# .  .  .  .  .  has already been calculated in this traversion
# .  .  .  .  -> S s104
# .  .  .  .  .  --- signals needed for s104 --
# .  .  .  .  .    (no signals needed)
# .  .  .  .  .  added s104 (double [1])
# .  .  .  .  added s105 (bool [1]) type proposal: (bool [1])
# .  .  .  added s106 (double [1]) type proposal: (double [1])
# .  .  added s107 (double [1]) type proposal: (double [1])
# .  -> S s111
# .  .  --- signals needed for s111 --
# .  .  -> S s108
# .  .  .  --- signals needed for s108 --
# .  .  .    (no signals needed)
# .  .  .  added s108 (double [1])
# .  .  -> S s110
# .  .  .  --- signals needed for s110 --
# .  .  .  -> S s107
# .  .  .  .  has already been calculated in this traversion
# .  .  .  -> S s109
# .  .  .  .  --- signals needed for s109 --
# .  .  .  .    (no signals needed)
# .  .  .  .  added s109 (double [1])
# .  .  .  added s110 (bool [1]) type proposal: (bool [1])
# .  .  added s111 (double [1]) type proposal: (double [1])
# .  added s112 (double [1]) type proposal: (double [1])
# -> S s116
# .  --- signals needed for s116 --
# .  -> S s113
# .  .  --- signals needed for s113 --
# .  .    (no signals needed)
# .  .  added s113 (double [1])
# .  -> S s115
# .  .  --- signals needed for s115 --
# .  .  -> S s107
# .  .  .  has already been calculated in this traversion
# .  .  -> S s114
# .  .  .  --- signals needed for s114 --
# .  .  .    (no signals needed)
# .  .  .  added s114 (double [1])
# .  .  added s115 (bool [1]) type proposal: (bool [1])
# .  added s116 (double [1]) type proposal: (double [1])
# added steering (double [1]) type proposal: (double [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - psi_r
#   - psi
#   - k_p
#   - Delta_l_r
#   - Delta_l
#   - velocity
#   - s92
#   - s95
#   - s101
#   - s103
#   - s104
#   - s108
#   - s109
#   - s113
#   - s114
# dependent sources (simulation inputs):
#   - k_p
#   - velocity
# dependent sources (through state-dependend blocks):
# execution order:
#   - s99
#   - Delta_l_r
#   - s89
#   - s90
#   - s91
#   - s92
#   - s93
#   - s94
#   - s95
#   - s96
#   - s97
#   - Delta_u
#   - s100
#   - s101
#   - s102
#   - s103
#   - s104
#   - s105
#   - s106
#   - s107
#   - s108
#   - s109
#   - s110
#   - s111
#   - s112
#   - s113
#   - s114
#   - s115
#   - s116
#   - steering
# blocks whose states must be updated:
# getExecutionLine on level 7
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - Delta_u
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 8
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - tracked_index
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 9
# --- signals needed for psi_r_dot --
# -> S v_star
# .  --- signals needed for v_star --
# .  -> S s69
# .  .  --- signals needed for s69 --
# .  .  -> S velocity
# .  .  .  has already been calculated in a previous traversion
# .  .  .  as it is also a simulation input, adding it to the list of depended inputs
# .  .  -> S s68
# .  .  .  --- signals needed for s68 --
# .  .  .  -> S Delta_u
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  added s68 (double [1]) type proposal: (double [1])
# .  .  added s69 (double [1]) type proposal: (double [1])
# .  -> S s72
# .  .  --- signals needed for s72 --
# .  .  -> S s70
# .  .  .  --- signals needed for s70 --
# .  .  .    (no signals needed)
# .  .  .  added s70 (double [1])
# .  .  -> S s71
# .  .  .  --- signals needed for s71 --
# .  .  .  -> S Delta_l
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  -> S s41
# .  .  .  .  --- signals needed for s41 --
# .  .  .  .  -> S s11
# .  .  .  .  .  --- signals needed *indirectly* for s11 (through state update) --
# .  .  .  .  .  --- signals needed for s11 --
# .  .  .  .  .    (no signals needed)
# .  .  .  .  .  added s11 (double [2725] [1])
# .  .  .  .  -> S s36
# .  .  .  .  .  has already been calculated in a previous traversion
# .  .  .  .  added s41 (double [1]) type proposal: (double [1])
# .  .  .  added s71 (double [1]) type proposal: (double [1])
# .  .  added s72 (double [1]) type proposal: (double [1])
# .  added v_star (double [1]) type proposal: (double [1])
# -> S s74
# .  --- signals needed for s74 --
# .  -> S s41
# .  .  has already been calculated in this traversion
# .  -> S s86
# .  .  --- signals needed for s86 --
# .  .  -> S s84
# .  .  .  --- signals needed for s84 --
# .  .  .  -> S psi_rr
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  -> S psi_r
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  added s84 (double [1]) type proposal: (double [1])
# .  .  -> S s85
# .  .  .  --- signals needed for s85 --
# .  .  .    (no signals needed)
# .  .  .  added s85 (double [1])
# .  .  added s86 (double [1]) type proposal: (double [1])
# .  added s74 (double [1]) type proposal: (double [1])
# added psi_r_dot (double [1]) type proposal: (double [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - velocity
#   - Delta_u
#   - s70
#   - Delta_l
#   - s11
#   - s36
#   - psi_rr
#   - psi_r
#   - s85
# dependent sources (simulation inputs):
#   - velocity
# dependent sources (through state-dependend blocks):
# execution order:
#   - s68
#   - s69
#   - s70
#   - s11
#   - s41
#   - s71
#   - s72
#   - v_star
#   - s84
#   - s85
#   - s86
#   - s74
#   - psi_r_dot
# blocks whose states must be updated:
#   - 7
# getExecutionLine on level 10
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - x_r
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 11
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - Delta_index
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 12
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - x
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 13
# --- signals needed for disturbed_steering --
# -> S s133
# .  --- signals needed for s133 --
# .  -> S s130
# .  .  --- signals needed for s130 --
# .  .  -> S steering
# .  .  .  has already been calculated in a previous traversion
# .  .  -> S s129
# .  .  .  --- signals needed for s129 --
# .  .  .  -> S steering_disturbance
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  -> S s5
# .  .  .  .  --- signals needed for s5 --
# .  .  .  .  -> S disturbance_amplitude
# .  .  .  .  .    --> crosses system bounds
# .  .  .  .  .  added input dependency disturbance_amplitude (double [1])
# .  .  .  .  -> S s4
# .  .  .  .  .  --- signals needed for s4 --
# .  .  .  .  .    (no signals needed)
# .  .  .  .  .  added s4 (double [1])
# .  .  .  .  added s5 (double [1]) type proposal: (double [1])
# .  .  .  added s129 (double [1]) type proposal: (double [1])
# .  .  added s130 (double [1]) type proposal: (double [1])
# .  -> S s132
# .  .  --- signals needed for s132 --
# .  .  -> S s130
# .  .  .  has already been calculated in this traversion
# .  .  -> S s131
# .  .  .  --- signals needed for s131 --
# .  .  .    (no signals needed)
# .  .  .  added s131 (double [1])
# .  .  added s132 (bool [1]) type proposal: (bool [1])
# .  added s133 (double [1]) type proposal: (double [1])
# -> S s135
# .  --- signals needed for s135 --
# .  -> S s133
# .  .  has already been calculated in this traversion
# .  -> S s134
# .  .  --- signals needed for s134 --
# .  .    (no signals needed)
# .  .  added s134 (double [1])
# .  added s135 (bool [1]) type proposal: (bool [1])
# added disturbed_steering (double [1]) type proposal: (double [1])
# ------ print of execution line -----
# dependent sources of any kind:
#   - steering
#   - steering_disturbance
#   - disturbance_amplitude
#   - s4
#   - s131
#   - s134
# dependent sources (simulation inputs):
#   - disturbance_amplitude
# dependent sources (through state-dependend blocks):
# execution order:
#   - s4
#   - s5
#   - s129
#   - s130
#   - s131
#   - s132
#   - s133
#   - s134
#   - s135
#   - disturbed_steering
# blocks whose states must be updated:
# getExecutionLine on level 14
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - psi_rr
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 15
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - v_star
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
# getExecutionLine on level 16
# has already been calculated in a previous traversion
# ------ print of execution line -----
# dependent sources of any kind:
#   - Delta_l_r
# dependent sources (simulation inputs):
# dependent sources (through state-dependend blocks):
# execution order:
# blocks whose states must be updated:
#
# -------- Build all execution paths  --------
#
# --------- Computing order 0 --------
# These sources are translated to (through their blocks via state-update):
# -- dependencySignalsThroughStates signals __ --
#   - s151
#   - s9
#   - s8
#   - x
#   - y
#   - s34
#   - s147
#   - s149
#   - tracked_index
#   - s126
#   - s76
#   - s78
# getExecutionLine on level 17
# --- signals needed for s151 --
# -> S psi
# .  has already been calculated in a previous traversion
# -> S s146
# .  --- signals needed for s146 --
# .  -> S s144
# .  .  --- signals needed for s144 --
# .  .  -> S velocity
# .  .  .  has already been calculated in a previous traversion
# .  .  .  as it is also a simulation input, adding it to the list of depended inputs
# .  .  -> S s143
# .  .  .  --- signals needed for s143 --
# .  .  .    (no signals needed)
# .  .  .  added s143 (double [1])
# .  .  added s144 (double [1]) type proposal: (double [1])
# .  -> S s145
# .  .  --- signals needed for s145 --
# .  .  -> S disturbed_steering
# .  .  .  has already been calculated in a previous traversion
# .  .  added s145 (double [1]) type proposal: (double [1])
# .  added s146 (double [1]) type proposal: (double [1])
# added s151 (double [1]) type proposal: (double [1])
# getExecutionLine on level 18
# has already been calculated in a previous traversion
# getExecutionLine on level 19
# has already been calculated in a previous traversion
# getExecutionLine on level 20
# has already been calculated in a previous traversion
# getExecutionLine on level 21
# has already been calculated in a previous traversion
# getExecutionLine on level 22
# has already been calculated in a previous traversion
# getExecutionLine on level 23
# --- signals needed for s147 --
# -> S x
# .  has already been calculated in a previous traversion
# -> S s139
# .  --- signals needed for s139 --
# .  -> S velocity
# .  .  has already been calculated in a previous traversion
# .  .  as it is also a simulation input, adding it to the list of depended inputs
# .  -> S s138
# .  .  --- signals needed for s138 --
# .  .  -> S s137
# .  .  .  --- signals needed for s137 --
# .  .  .  -> S disturbed_steering
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  -> S psi
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  added s137 (double [1]) type proposal: (double [1])
# .  .  added s138 (double [1]) type proposal: (double [1])
# .  added s139 (double [1]) type proposal: (double [1])
# added s147 (double [1]) type proposal: (double [1])
# getExecutionLine on level 24
# --- signals needed for s149 --
# -> S y
# .  has already been calculated in a previous traversion
# -> S s142
# .  --- signals needed for s142 --
# .  -> S velocity
# .  .  has already been calculated in a previous traversion
# .  .  as it is also a simulation input, adding it to the list of depended inputs
# .  -> S s141
# .  .  --- signals needed for s141 --
# .  .  -> S s140
# .  .  .  --- signals needed for s140 --
# .  .  .  -> S disturbed_steering
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  -> S psi
# .  .  .  .  has already been calculated in a previous traversion
# .  .  .  added s140 (double [1]) type proposal: (double [1])
# .  .  added s141 (double [1]) type proposal: (double [1])
# .  added s142 (double [1]) type proposal: (double [1])
# added s149 (double [1]) type proposal: (double [1])
# getExecutionLine on level 25
# has already been calculated in a previous traversion
# getExecutionLine on level 26
# --- signals needed for s126 --
# -> S s127
# .  has already been calculated in a previous traversion
# -> S s125
# .  --- signals needed for s125 --
# .  -> S s124_stepwidth
# .  .  --- signals needed for s124_stepwidth --
# .  .  -> S s120
# .  .  .  --- signals needed for s120 --
# .  .  .    (no signals needed)
# .  .  .  added s120 (int32_t [1])
# .  .  -> S s123_paused
# .  .  .  --- signals needed *indirectly* for s123_paused (through state update) --
# .  .  .  -> S s122
# .  .  .  -> S s118
# .  .  .  --- signals needed for s123_paused --
# .  .  .    (no signals needed)
# .  .  .  added s123_paused (bool [1]) type proposal: (bool [1])
# .  .  added s124_stepwidth (int32_t [1]) type proposal: (int32_t [1])
# .  -> S s122
# .  .  --- signals needed for s122 --
# .  .  -> S s127
# .  .  .  has already been calculated in a previous traversion
# .  .  -> S s121
# .  .  .  --- signals needed for s121 --
# .  .  .    (no signals needed)
# .  .  .  added s121 (int32_t [1])
# .  .  added s122 (bool [1]) type proposal: (bool [1])
# .  added s125 (int32_t [1]) type proposal: (int32_t [1])
# added s126 (int32_t [1]) type proposal: (int32_t [1])
# getExecutionLine on level 27
# --- signals needed for s76 --
# -> S psi_r
# .  has already been calculated in a previous traversion
# -> S psi_r_dot
# .  has already been calculated in a previous traversion
# added s76 (double [1]) type proposal: (double [1])
# getExecutionLine on level 28
# --- signals needed for s78 --
# -> S s79_shared_couter
# .  has already been calculated in a previous traversion
# -> S s77
# .  --- signals needed for s77 --
# .    (no signals needed)
# .  added s77 (int32_t [1])
# added s78 (int32_t [1]) type proposal: (int32_t [1])
# state update of blocks that yield the following output signals:
# --------- Computing order 1 --------
# These sources are translated to (through their blocks via state-update):
# -- dependencySignalsThroughStates signals __ --
#   - s122
#   - s118
# getExecutionLine on level 29
# has already been calculated in a previous traversion
# getExecutionLine on level 30
# --- signals needed for s118 --
# -> S s79_shared_couter
# .  has already been calculated in a previous traversion
# -> S sample_disturbance
# .    --> crosses system bounds
# .  added input dependency sample_disturbance (int32_t [1])
# added s118 (bool [1]) type proposal: (bool [1])
# state update of blocks that yield the following output signals:
# --------- Computing order 2 --------
# These sources are translated to (through their blocks via state-update):
# -- dependencySignalsThroughStates signals __ --
# state update of blocks that yield the following output signals:
# All dependencies are resolved
#
#
#
# Code generation folder generated/path_curvature_following_control
# Running compiler: emcc --bind -s MODULARIZE=1 -s EXPORT_NAME="ORTD_simulator" generated/path_curvature_following_control/main.cpp -g4 -s -o generated/path_curvature_following_control/main.js
# Compilation result:  0

# %%
import IPython
IPython.display.IFrame(src='../vehicle_control_tutorial/path_curvature_following_control.html', width='100%', height=1000)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="../vehicle_control_tutorial/path_curvature_following_control.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
